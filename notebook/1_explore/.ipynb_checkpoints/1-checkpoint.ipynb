# %%
import pandas as pd

# %%
y_train  = pd.read_csv('../../data/raw/y_train.csv')
demographic = pd.read_csv('../../data/raw/demo.csv')
address = pd.read_csv('../../data/raw/adr.csv')
saving_acc = pd.read_csv('../../data/raw/sa.csv')
cc_transaction = pd.read_csv('../../data/raw/cc_txn.csv')

# %%
category = pd.read_csv('../../data/not_raw/cat.csv')

# %% [markdown]
# ------------------

# %%
y_train.head()
# Out:
#    ip_id  label
# 0      1    0.0
# 1      2    0.0
# 2      3    0.0
# 3      4    0.0
# 4      5    0.0

# %%
y_train.shape
# Out:
# (6361, 2)

# %%
len(y_train['ip_id'].unique())
# Out:
# 6361

# %%
len(y_train[y_train['label'] == 0])
# Out:
# 5947

# %%
len(y_train[y_train['label'] == 1])
# Out:
# 414

# %%
len(y_train[y_train['label'] == 1])/len(y_train[y_train['label'] == 0])
# Out:
# 0.06961493189843619

# %% [markdown]
# y uniqe ดังนั้นจะใช้อันนี้เป็นแกน แล้ว merge ตารางอื่นเข้าหา

# %% [markdown]
# -----------------------------

# %%
demographic.head()
# Out:
#    ip_id  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income   crn_bal  gnd_cd  \
# 0      1   1990.0  2011-12-11             0.0     45864.0  876428.0     2.0
# 1      2   1986.0  2010-06-08             1.0     43355.0  540649.0     2.0
# 2      3   1983.0  2013-12-06             0.0     48836.0  310503.0     2.0
# 3      4   1984.0  2009-12-27             0.0     44397.0   34209.0     2.0
# 4      5   1986.0  2006-09-01             1.0     43281.0   39963.0     2.0
#
#    mar_st_cd  ctf_tp_cd  ocp_cd
# 0        2.0        3.0       9
# 1        2.0        1.0       3
# 2        2.0        2.0      12
# 3        2.0        5.0      11
# 4        3.0        6.0       9

# %%
demographic.shape
# Out:
# (10299, 10)

# %%
len(demographic['ip_id'].unique())
# Out:
# 10299

# %% [markdown]
# --------------------------------

# %% [markdown]
# ที่อยู่อาศัย

# %%
address[0:10]
# Out:
#    ip_id                                      prov
# 0      2  ลำพูน
# 1      6  นครปฐม
# 2      6  นครราชสีมา
# 3      8  นครราชสีมา
# 4     12  ปทุมธานี
# 5     12  อุตรดิตถ์
# 6     14  พังงา
# 7     14  ภูเก็ต
# 8     14  มุกดาหาร
# 9     16  ปัตตานี

# %%
address.shape
# Out:
# (4737, 2)

# %%
len(address['ip_id'].unique())
# Out:
# 3633

# %%
address['prov'].unique()
# Out:
# array(['ลำพูน                                   ',
#        'นครปฐม                                  ',
#        'นครราชสีมา                              ',
#        'ปทุมธานี                                ',
#        'อุตรดิตถ์                               ',
#        'พังงา                                   ',
#        'ภูเก็ต                                  ',
#        'มุกดาหาร                                ',
#        'ปัตตานี                                 ',
#        'เชียงราย                                ',
#        'สิงห์บุรี                               ',
#        'นนทบุรี                                 ',
#        'นครนายก                                 ',
#        'ตรัง                                    ',
#        'กำแพงเพชร                               ',
#        'ขอนแก่น                                 ',
#        'ระยอง                                   ',
#        'ปราจีนบุรี                              ',
#        'ระนอง                                   ',
#        'แม่ฮ่องสอน                              ',
#        'อุดรธานี                                ',
#        'หนองบัวลำภู                             ',
#        'นราธิวาส                                ',
#        'กระบี่                                  ',
#        'อ่างทอง                                 ',
#        'บุรีรัมย์                               ',
#        'ตาก                                     ',
#        'สระแก้ว                                 ',
#        'พิษณุโลก                                ',
#        'ยโสธร                                   ',
#        'ชลบุรี                                  ',
#        'สุราษฎร์ธานี                            ',
#        'พะเยา                                   ',
#        'ลำปาง                                   ',
#        'ตราด                                    ',
#        'เพชรบูรณ์                               ',
#        'กาฬสินธุ์                               ',
#        'บึงกาฬ                                  ',
#        'ราชบุรี                                 ',
#        'สุรินทร์                                ',
#        'สมุทรสาคร                               ',
#        'นครพนม                                  ',
#        'สมุทรปราการ                             ',
#        'กทม.                                    ',
#        'นครศรีธรรมราช                           ',
#        'พระนครศรีอยุธยา                         ',
#        'สงขลา                                   ',
#        'ชุมพร                                   ',
#        'อุบลราชธานี                             ',
#        'พิจิตร                                  ',
#        'ร้อยเอ็ด                                ',
#        'นครสวรรค์                               ',
#        'สกลนคร                                  ',
#        'ฉะเชิงเทรา                              ',
#        'หนองคาย                                 ',
#        'สระบุรี                                 ',
#        'เชียงใหม่                               ',
#        'จันทบุรี                                ',
#        'น่าน                                    ',
#        'สุพรรณบุรี                              ',
#        'ศรีสะเกษ                                ',
#        'เลย                                     ',
#        'ชัยภูมิ                                 ',
#        'ลพบุรี                                  ',
#        'สมุทรสงคราม                             ',
#        'พัทลุง                                  ',
#        'แพร่                                    ',
#        'กาญจนบุรี                               ',
#        'มหาสารคาม                               ',
#        'ประจวบคีรีขันธ์                         ',
#        'ชัยนาท                                  '], dtype=object)

# %% [markdown]
# ทำไมทั้งหมดกับ uniqe ไม่เหมือนกันวะ แสดงว่าคนนึงอยู่ได้หลายจังหวัด

# %% [markdown]
# ----------------------------

# %%
saving_acc[0:10]
# Out:
#    ip_id          dt           channel  tp     amt
# 0      1  2017-02-06               EDC  DR  1045.0
# 1      1  2017-02-28            Branch  CR   995.0
# 2      1  2017-03-15             KPlus  DR  6311.0
# 3      1  2017-03-22             KPlus  CR   884.0
# 4      1  2017-03-26            Branch  DR  4890.0
# 5      1  2017-03-29               ATM  CR  5955.0
# 6      1  2017-03-30               CDM  CR  6879.0
# 7      1  2017-04-02  CorporateConnect  CR  3082.0
# 8      1  2017-04-10               ATM  DR   735.0
# 9      1  2017-04-20               ATM  DR  1278.0

# %%
saving_acc['channel'].unique()
# Out:
# array(['EDC', 'Branch', 'KPlus', 'ATM', 'CDM', 'CorporateConnect'],
#       dtype=object)

# %%
saving_acc.shape
# Out:
# (478658, 5)

# %%
len(saving_acc['ip_id'].unique())
# Out:
# 9963

# %% [markdown]
# ให้มาเกินคนที่เรามีข้อมูล บางส่วนเป็นของคนที่เราไม่มีข้อมูลว่าแม่งโกงป่าว

# %% [markdown]
# -------------------

# %%
cc_transaction[0:10]
# Out:
#    ip_id          dt category   card  txn_amt
# 0      1  2017-02-02     cat2  card1  13150.0
# 1      1  2017-02-06    cat15  card2   9786.0
# 2      1  2017-02-12     cat2  card1  11165.0
# 3      1  2017-02-15    cat15  card1   8948.0
# 4      1  2017-02-18     cat3  card2   4609.0
# 5      1  2017-02-19     cat8  card3   3924.0
# 6      1  2017-02-21     cat7  card2   2874.0
# 7      1  2017-02-24    cat14  card2   9589.0
# 8      1  2017-02-24    cat15  card2   6025.0
# 9      1  2017-02-26    cat11  card3    494.0

# %%
cc_transaction.shape
# Out:
# (627894, 5)

# %%
len(cc_transaction['ip_id'].unique())
# Out:
# 7488

# %% [markdown]
# เช่นกันกับการฝากเงิน

# %%
cc_transaction['category'].unique()
# Out:
# array(['cat2', 'cat15', 'cat3', 'cat8', 'cat7', 'cat14', 'cat11', 'cat10',
#        'cat9', 'cat4', 'cat1', 'cat16', 'cat5', 'cat6', 'cat12', 'cat13'],
#       dtype=object)

# %%
cc_transaction['card'].unique()
# Out:
# array(['card1', 'card2', 'card3'], dtype=object)

# %% [markdown]
# ----------------

# %%
category
# Out:
#        no                        main_category
# 0    cat1                  Fashion and Apparel
# 1    cat9                               Sports
# 2    cat2                    Health and beauty
# 3   cat10                             Children
# 4    cat3                    Food and Beverage
# 5   cat11                             Services
# 6    cat4            Appliance and Electronics
# 7   cat12                            Education
# 8    cat5  Office supplies books and gift shop
# 9   cat13                                  Pet
# 10   cat6        Automotive shops and Vehicles
# 11  cat14                               Travel
# 12   cat7                        Entertainment
# 13  cat15                        Accommodation
# 14   cat8                      Home and Garden
# 15  cat16                               Others

# %% [markdown]
# ---------------------------

# %%
result1 = pd.merge(y_train, demographic, how='left', on=['ip_id', 'ip_id'])

# %%
result1.shape
# Out:
# (6361, 11)

# %%
result1.head()
# Out:
#    ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income   crn_bal  \
# 0      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 1      2    0.0   1986.0  2010-06-08             1.0     43355.0  540649.0
# 2      3    0.0   1983.0  2013-12-06             0.0     48836.0  310503.0
# 3      4    0.0   1984.0  2009-12-27             0.0     44397.0   34209.0
# 4      5    0.0   1986.0  2006-09-01             1.0     43281.0   39963.0
#
#    gnd_cd  mar_st_cd  ctf_tp_cd  ocp_cd
# 0     2.0        2.0        3.0       9
# 1     2.0        2.0        1.0       3
# 2     2.0        2.0        2.0      12
# 3     2.0        2.0        5.0      11
# 4     2.0        3.0        6.0       9

# %% [markdown]
# --------------------

# %%
result2 = pd.merge(result1, address, how='left', on=['ip_id', 'ip_id'])

# %%
result2.shape
# Out:
# (7465, 12)

# %% [markdown]
# จะเห็นว่าแถวเพิ่มขึ้นแสดงว่ามันแตกเป็นหลายแถวที่มีจังหวัดต่างกัน

# %%
result2[0:10]
# Out:
#    ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income    crn_bal  \
# 0      1    0.0   1990.0  2011-12-11             0.0     45864.0   876428.0
# 1      2    0.0   1986.0  2010-06-08             1.0     43355.0   540649.0
# 2      3    0.0   1983.0  2013-12-06             0.0     48836.0   310503.0
# 3      4    0.0   1984.0  2009-12-27             0.0     44397.0    34209.0
# 4      5    0.0   1986.0  2006-09-01             1.0     43281.0    39963.0
# 5      6    0.0   1987.0  2005-06-17             0.0     49867.0   590634.0
# 6      6    0.0   1987.0  2005-06-17             0.0     49867.0   590634.0
# 7      7    0.0   1984.0  2014-07-30             1.0     42205.0      500.0
# 8      8    0.0   1976.0  2014-06-27             0.0     42422.0   845055.0
# 9      9    0.0   1983.0  2006-04-21             1.0     38264.0  1717875.0
#
#    gnd_cd  mar_st_cd  ctf_tp_cd  ocp_cd  \
# 0     2.0        2.0        3.0       9
# 1     2.0        2.0        1.0       3
# 2     2.0        2.0        2.0      12
# 3     2.0        2.0        5.0      11
# 4     2.0        3.0        6.0       9
# 5     2.0        4.0        2.0      12
# 6     2.0        4.0        2.0      12
# 7     2.0        3.0        2.0       6
# 8     2.0        2.0        6.0       2
# 9     1.0        2.0        3.0       2
#
#                                        prov
# 0                                       NaN
# 1  ลำพูน
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5  นครปฐม
# 6  นครราชสีมา
# 7                                       NaN
# 8  นครราชสีมา
# 9                                       NaN

# %%
result2.to_csv('../../data/not_raw/demo_with_address.csv', index=False)

# %% [markdown]
# ------------

# %%
result3 = pd.merge(result1, saving_acc, how='left', on=['ip_id', 'ip_id'])

# %%
result3.shape
# Out:
# (238896, 15)

# %%
result3[0:10]
# Out:
#    ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income   crn_bal  \
# 0      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 1      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 2      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 3      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 4      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 5      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 6      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 7      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 8      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 9      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
#
#    gnd_cd  mar_st_cd  ctf_tp_cd  ocp_cd          dt           channel  tp  \
# 0     2.0        2.0        3.0       9  2017-02-06               EDC  DR
# 1     2.0        2.0        3.0       9  2017-02-28            Branch  CR
# 2     2.0        2.0        3.0       9  2017-03-15             KPlus  DR
# 3     2.0        2.0        3.0       9  2017-03-22             KPlus  CR
# 4     2.0        2.0        3.0       9  2017-03-26            Branch  DR
# 5     2.0        2.0        3.0       9  2017-03-29               ATM  CR
# 6     2.0        2.0        3.0       9  2017-03-30               CDM  CR
# 7     2.0        2.0        3.0       9  2017-04-02  CorporateConnect  CR
# 8     2.0        2.0        3.0       9  2017-04-10               ATM  DR
# 9     2.0        2.0        3.0       9  2017-04-20               ATM  DR
#
#       amt
# 0  1045.0
# 1   995.0
# 2  6311.0
# 3   884.0
# 4  4890.0
# 5  5955.0
# 6  6879.0
# 7  3082.0
# 8   735.0
# 9  1278.0

# %%
len(result3['ip_id'].unique())
# Out:
# 6361

# %%
result3.to_csv('../../data/not_raw/demo_with_saving_acc.csv', index=False)

# %% [markdown]
# --------------------------------------------------

# %%
result4 = pd.merge(result1, cc_transaction, how='left', on=['ip_id', 'ip_id'])

# %%
result4.shape
# Out:
# (608588, 15)

# %%
result4[0:10]
# Out:
#    ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income   crn_bal  \
# 0      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 1      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 2      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 3      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 4      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 5      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 6      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 7      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 8      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
# 9      1    0.0   1990.0  2011-12-11             0.0     45864.0  876428.0
#
#    gnd_cd  mar_st_cd  ctf_tp_cd  ocp_cd          dt category   card  txn_amt
# 0     2.0        2.0        3.0       9  2017-02-02     cat2  card1  13150.0
# 1     2.0        2.0        3.0       9  2017-02-06    cat15  card2   9786.0
# 2     2.0        2.0        3.0       9  2017-02-12     cat2  card1  11165.0
# 3     2.0        2.0        3.0       9  2017-02-15    cat15  card1   8948.0
# 4     2.0        2.0        3.0       9  2017-02-18     cat3  card2   4609.0
# 5     2.0        2.0        3.0       9  2017-02-19     cat8  card3   3924.0
# 6     2.0        2.0        3.0       9  2017-02-21     cat7  card2   2874.0
# 7     2.0        2.0        3.0       9  2017-02-24    cat14  card2   9589.0
# 8     2.0        2.0        3.0       9  2017-02-24    cat15  card2   6025.0
# 9     2.0        2.0        3.0       9  2017-02-26    cat11  card3    494.0

# %%
len(result4['ip_id'].unique())
# Out:
# 6361

# %%
result4.to_csv('../../data/not_raw/demo_with_cc_transaction.csv', index=False)

# %%
meanr4 = result4.groupby(['ip_id']).mean()

# %%
over10000 = meanr4[meanr4['txn_amt'] > 10000]

# %%
over10000[over10000['label'] == 1].shape
# Out:
# (414, 10)

# %% [markdown]
# # ทุกคนที่ค่าเฉลี่ยใช้บัตรเครดิตเกิน 10000 ต่อเดือน ทุกคน เบี้ยวหนี้หมด 100%

# %% [markdown]
# -----------------------

# %%
result1[result1['brth_yr'] > 1996]
# Out:
#       ip_id  label  brth_yr act_strt_dt  no_of_dpnd_chl  cis_income  \
# 2184   2185    0.0   1998.0  2012-07-28             0.0     43830.0
# 3607   3608    0.0   1997.0  2011-09-17             0.0     43435.0
# 5954   5955    1.0   2003.0  2011-03-24             0.0     51307.0
# 5963   5964    1.0   2005.0  2010-01-10             0.0     54925.0
# 5976   5977    1.0   1999.0  2018-01-11             0.0     46516.0
# 5979   5980    1.0   2005.0  1999-05-23             1.0     28653.0
# 5980   5981    1.0   2005.0  2000-12-09             0.0     74134.0
# 5986   5987    1.0   2005.0  2018-01-11             0.0     22418.0
# 5987   5988    1.0   2005.0  1997-11-17             0.0     28716.0
# 5993   5994    1.0   2003.0  2008-09-20             4.0     41119.0
# 6004   6005    1.0   2005.0  2018-01-11             0.0     61630.0
# 6014   6015    1.0   2000.0  1999-12-21             0.0     42817.0
# 6015   6016    1.0   2000.0  2008-03-18             1.0     14279.0
# 6023   6024    1.0   1998.0  2008-09-17             0.0     44081.0
# 6030   6031    1.0   2005.0  2010-02-26             0.0     47678.0
# 6033   6034    1.0   1997.0  2002-07-10             2.0     53536.0
# 6041   6042    1.0   2005.0  1989-06-28             0.0     54444.0
# 6048   6049    1.0   1997.0  2009-12-21             1.0     39890.0
# 6057   6058    1.0   2005.0  2000-06-01             5.0     40543.0
# 6059   6060    1.0   1997.0  2002-11-18             0.0     31913.0
# 6069   6070    1.0   2005.0  2016-02-29             0.0     26358.0
# 6073   6074    1.0   2005.0  2018-01-11             3.0     23843.0
# 6078   6079    1.0   2004.0  2015-01-07             0.0     17160.0
# 6081   6082    1.0   2004.0  1992-09-16             1.0     48011.0
# 6091   6092    1.0   2005.0  2017-07-07             0.0     40576.0
# 6094   6095    1.0   2005.0  2013-01-13             0.0     49239.0
# 6100   6101    1.0   1999.0  2018-01-11             0.0     49669.0
# 6102   6103    1.0   1997.0  2018-01-11             1.0     17901.0
# 6108   6109    1.0   2005.0  2018-01-11             0.0     49875.0
# 6114   6115    1.0   1997.0  2011-04-26             2.0     58525.0
# ...     ...    ...      ...         ...             ...         ...
# 6200   6201    1.0   2005.0  1996-10-02             0.0     37491.0
# 6201   6202    1.0   2000.0  1991-05-01             4.0     42913.0
# 6207   6208    1.0   1998.0  2009-06-27             0.0     51950.0
# 6212   6213    1.0   1998.0  1998-08-27             4.0     37184.0
# 6218   6219    1.0   2005.0  2009-05-10             0.0     68152.0
# 6226   6227    1.0   2005.0  2018-01-11             0.0     67326.0
# 6228   6229    1.0   2004.0  2000-01-04             0.0     75289.0
# 6229   6230    1.0   2003.0  2018-01-11             0.0     23067.0
# 6244   6245    1.0   2002.0  2018-01-11             0.0     55936.0
# 6247   6248    1.0   2002.0  2006-09-16             2.0     21906.0
# 6250   6251    1.0   2004.0  2007-10-31             0.0     44520.0
# 6251   6252    1.0   1998.0  2005-03-25             0.0     30833.0
# 6260   6261    1.0   2005.0  1986-07-08             0.0     34484.0
# 6263   6264    1.0   2004.0  2017-08-07             0.0     49041.0
# 6267   6268    1.0   1999.0  2013-11-21             0.0     55977.0
# 6270   6271    1.0   2002.0  1979-12-26             3.0     38729.0
# 6274   6275    1.0   1998.0  2018-01-11             0.0     10370.0
# 6279   6280    1.0   2005.0  2002-10-19             0.0     77486.0
# 6286   6287    1.0   2005.0  2017-01-15             0.0     43364.0
# 6289   6290    1.0   1999.0  2012-07-04             0.0     54254.0
# 6295   6296    1.0   1999.0  2014-05-29             0.0     35109.0
# 6297   6298    1.0   2005.0  2018-01-11             0.0     54476.0
# 6303   6304    1.0   1997.0  2014-02-12             0.0     22428.0
# 6306   6307    1.0   1997.0  2017-03-22             0.0     35856.0
# 6307   6308    1.0   2000.0  2006-01-02             0.0     40508.0
# 6319   6320    1.0   2003.0  1999-01-03             3.0     69919.0
# 6338   6339    1.0   2003.0  2018-01-11             3.0     59800.0
# 6340   6341    1.0   2005.0  2005-02-28             0.0     48562.0
# 6350   6351    1.0   2005.0  2001-04-06             0.0     55708.0
# 6352   6353    1.0   2003.0  2018-01-11             0.0     44408.0
#
#         crn_bal  gnd_cd  mar_st_cd  ctf_tp_cd  ocp_cd
# 2184      500.0     1.0        4.0        1.0       5
# 3607      500.0     1.0        4.0        3.0       8
# 5954      500.0     2.0        3.0        1.0       7
# 5963  1069543.0     1.0        1.0        5.0       5
# 5976  1218792.0     1.0        1.0        4.0       8
# 5979  1407177.0     2.0        4.0        3.0       5
# 5980  2731963.0     1.0        1.0        6.0       7
# 5986   880852.0     2.0        1.0        6.0       4
# 5987      500.0     1.0        3.0        2.0       5
# 5993  1282647.0     2.0        1.0        6.0       2
# 6004  2212760.0     1.0        2.0        6.0       9
# 6014  4021908.0     1.0        2.0        6.0       8
# 6015  3300791.0     2.0        1.0        2.0       9
# 6023  1687896.0     2.0        2.0        1.0       1
# 6030      500.0     1.0        1.0        4.0       8
# 6033  5182033.0     1.0        1.0        2.0       3
# 6041      500.0     1.0        1.0        1.0       5
# 6048      500.0     1.0        3.0        3.0       3
# 6057  6204189.0     2.0        1.0        4.0      12
# 6059  1523768.0     1.0        2.0        5.0       4
# 6069   606426.0     1.0        4.0        6.0       4
# 6073      500.0     2.0        3.0        1.0       6
# 6078   857562.0     1.0        1.0        5.0       1
# 6081      500.0     1.0        4.0        1.0       2
# 6091   253049.0     1.0        1.0        1.0       8
# 6094  1094894.0     2.0        1.0        2.0       3
# 6100  1713827.0     2.0        4.0        6.0       3
# 6102      500.0     1.0        3.0        3.0       7
# 6108      500.0     2.0        1.0        2.0       2
# 6114      500.0     1.0        4.0        5.0       8
# ...         ...     ...        ...        ...     ...
# 6200   140126.0     1.0        4.0        4.0       1
# 6201   489481.0     2.0        1.0        2.0      12
# 6207      500.0     2.0        4.0        3.0       3
# 6212  1571457.0     2.0        4.0        2.0       1
# 6218      500.0     2.0        2.0        4.0       2
# 6226      500.0     2.0        2.0        2.0       8
# 6228  2990694.0     1.0        3.0        4.0       9
# 6229      500.0     2.0        3.0        3.0       9
# 6244      500.0     2.0        1.0        2.0       5
# 6247  2460714.0     1.0        2.0        5.0       8
# 6250  4778332.0     1.0        3.0        1.0       2
# 6251      500.0     1.0        3.0        3.0       9
# 6260      500.0     2.0        2.0        6.0       7
# 6263  3272032.0     1.0        2.0        4.0      12
# 6267   779000.0     2.0        2.0        5.0       6
# 6270      500.0     1.0        3.0        4.0      12
# 6274  2254864.0     2.0        4.0        2.0       2
# 6279      500.0     2.0        3.0        3.0       6
# 6286  4231533.0     1.0        4.0        2.0       7
# 6289   231076.0     2.0        1.0        2.0       7
# 6295  2358892.0     2.0        4.0        3.0       2
# 6297      500.0     1.0        4.0        2.0       1
# 6303      500.0     2.0        1.0        4.0       8
# 6306   739951.0     2.0        4.0        1.0       7
# 6307      500.0     1.0        2.0        5.0       3
# 6319   720915.0     2.0        4.0        4.0       4
# 6338  2075387.0     1.0        3.0        4.0      12
# 6340   933538.0     1.0        2.0        3.0       8
# 6350      500.0     1.0        1.0        5.0       7
# 6352      500.0     2.0        4.0        4.0       8
#
# [74 rows x 11 columns]
